# %% [markdown]
# # ESG GNN Analysis
#
# Notebook placeholder for exploratory ESG graph analysis.

# %%
import sys
sys.path.append('../src')
from data_preprocessing import load_sample_esg_data, add_composite_score
add_composite_score(load_sample_esg_data())
